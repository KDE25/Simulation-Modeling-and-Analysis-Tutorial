# %% [markdown]
# # Data : Feature Engineering

# %% [markdown]
# Table Of Contents
# - Data
# - EDA
# - Model 1
# - Model 2

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import PolynomialFeatures

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import classification_report

# %%
wine = pd.read_csv('white_wine.csv')

# %%
wine
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.0              0.27         0.36            20.7      0.045
# 1              6.3              0.30         0.34             1.6      0.049
# 2              8.1              0.28         0.40             6.9      0.050
# 3              7.2              0.23         0.32             8.5      0.058
# 4              7.2              0.23         0.32             8.5      0.058
# ..             ...               ...          ...             ...        ...
# 515            6.1              0.31         0.26             2.2      0.051
# 516            6.8              0.18         0.37             1.6      0.055
# 517            7.4              0.15         0.42             1.7      0.045
# 518            5.9              0.13         0.28             1.9      0.050
# 519            7.2              0.34         0.34            12.6      0.048
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   45.0                 170.0   1.0010  3.00       0.45
# 1                   14.0                 132.0   0.9940  3.30       0.49
# 2                   30.0                  97.0   0.9951  3.26       0.44
# 3                   47.0                 186.0   0.9956  3.19       0.40
# 4                   47.0                 186.0   0.9956  3.19       0.40
# ..                   ...                   ...      ...   ...        ...
# 515                 28.0                 167.0   0.9926  3.37       0.47
# 516                 47.0                 154.0   0.9934  3.08       0.45
# 517                 49.0                 154.0   0.9920  3.00       0.60
# 518                 20.0                  78.0   0.9918  3.43       0.64
# 519                  7.0                  41.0   0.9940   NaN        NaN
#
#      alcohol  quality
# 0        8.8      6.0
# 1        9.5      6.0
# 2       10.1      6.0
# 3        9.9      6.0
# 4        9.9      6.0
# ..       ...      ...
# 515     10.4      6.0
# 516      9.1      5.0
# 517     10.4      6.0
# 518     10.8      6.0
# 519      NaN      NaN
#
# [520 rows x 12 columns]

# %% [markdown]
# > ## EDA

# %% [markdown]
# We will be doing some EDA to check the target variabel distribution. The target variabel distribution is
# 1. (+) a good quality wine : quality > 6 (18.9%)
# 1. (-) a bad quality wine : quality <= 6 (81.1%)

# %% [markdown]
# You will find that the distribution is imbalanced with 18.9 % positive class and 81.1 % negative class. The minority class is the good quality one, we migh more interest to detect a wine with good quality than the common one.

# %%
wine['alcohol'].fillna(wine['alcohol'].mean(),inplace = True)
wine['label'] = np.where(wine['quality']>6,1,0)
wine['label'].value_counts()/wine.shape[0]*100
# Out:
# /tmp/ipython-input-694351182.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wine['alcohol'].fillna(wine['alcohol'].mean(),inplace = True)
# label
# 0    81.153846
# 1    18.846154
# Name: count, dtype: float64

# %% [markdown]
# We will develope the model only using two features alcohol and density. Using the scatterplot you can see how those feature can differentiate the wine quality. Genrally, wine with good quality has high alcohol and high density.

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(x = 'alcohol', y = 'density',data = wine, hue = 'label')
plt.xlabel('Alcohol', fontsize = 23)
plt.ylabel('Density', fontsize = 23)
# Out:
# Text(0, 0.5, 'Density')

# %% [markdown]
# > ## Data Splitting

# %%
X = wine[['density','alcohol']]
y = wine['label']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, stratify = y, random_state = 2020)

# %% [markdown]
# > ## MODEL 1 : without polynomial

# %%
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logreg.predict(X_test)
print('performance \n',classification_report(y_test,y_pred))
# Out:
# performance
#                precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91       106
#            1       0.69      0.38      0.49        24
#
#     accuracy                           0.85       130
#    macro avg       0.78      0.67      0.70       130
# weighted avg       0.84      0.85      0.84       130

# %% [markdown]
# From illustration abovel, you can see the performance of the machine learning model. Let's say our concern is to these three metrics:
# 1. precision (+) : 0.69
# 1. recall (+) : 0.38
# 1. f1-score (+) : 0.49
#
# <br>
# next, we will do the modeling process with adding polynomial features and see the changes.

# %% [markdown]
# > ## MODEL 2 : with polynomial

# %%
poly = PolynomialFeatures(degree = 3, interaction_only=False,include_bias=False)
poly.fit(X_train)
X_train_poly = poly.transform(X_train)
X_test_poly = poly.transform(X_test)

# %%
logreg = LogisticRegression(max_iter = 1000)
logreg.fit(X_train_poly,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = logreg.predict(X_test_poly)
print('performance \n',classification_report(y_test,y_pred))
# Out:
# performance
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       106
#            1       0.95      0.88      0.91        24
#
#     accuracy                           0.97       130
#    macro avg       0.96      0.93      0.95       130
# weighted avg       0.97      0.97      0.97       130

# %% [markdown]
# From illustration abovel, you can see the performance improvement of the machine learning model. The changes of the three metrics:
# 1. precision (+) : from 0.69 to 0.95
# 1. recall (+) : from 0.38 to 0.88
# 1. f1-score (+) : from 0.49 to 0.91

# %% [markdown]
# > # Resampling Method : Non Performing Loan

# %% [markdown]
# To use some balancing technique you will need to install imblearn library.

# %%
# !pip install imblearn
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.12/dist-packages (from imblearn) (0.14.1)
# Requirement already satisfied: numpy<3,>=1.25.2 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn->imblearn) (2.0.2)
# Requirement already satisfied: scipy<2,>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn->imblearn) (1.16.3)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn->imblearn) (1.6.1)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn->imblearn) (0.1.5)
# Requirement already satisfied: joblib<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn->imblearn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn->imblearn) (3.6.0)
# Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Installing collected packages: imblearn
# Successfully installed imblearn-0.0

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler, NearMiss

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import classification_report, f1_score
import warnings

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %% [markdown]
# Dataset used in this illustration is bankloan.csv. with :
# 1. target : defaut
# 1. features : employ, debtinc, creddebt, othdebt

# %%
bankloan = pd.read_csv('bankloan.csv')

# %%
fitur = ['employ', 'debtinc', 'creddebt', 'othdebt']
target = ['default']

# %%
X = bankloan[fitur]
y = bankloan[target]

# %% [markdown]
# > ## EDA

# %%
bankloan['default'].value_counts()/bankloan.shape[0]*100
# Out:
# default
# 0    73.857143
# 1    26.142857
# Name: count, dtype: float64

# %% [markdown]
# This can be seen as imbalance classification problem because the target variabel distribution is imbalanced:
# 1. (+) default (26.1%)
# 1. (-) non-default (73.9%)

# %% [markdown]
# > ## Data Splitting

# %% [markdown]
# Data splitting scenario is train 60%, validation 20%, test 20%.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X,
    y,
    stratify = y,
    test_size = 0.2,
    random_state = 1899)

X_train, X_val, y_train, y_val = train_test_split(
    X_train_val,
    y_train_val,
    stratify = y_train_val,
    test_size = 0.25,
    random_state = 1899)

# %% [markdown]
# In the modeling process we will try some method and choose the best method based on f1 score. Those methods are :
# 1. logistic regression without any treatment
# 1. logistic regression that otimized by the threshold
# 1. logistic regression with random undersampling
# 1. Penalized logistic regression

# %% [markdown]
# > ## No Treatment

# %% [markdown]
# scenario :
# 1. metrics : f1-score
# 1. benchmark
# 1. threshold optimization

# %% [markdown]
# BENCHMARK

# %%
model = LogisticRegression()
model.fit(X_train_val, y_train_val)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.87       103
#            1       0.68      0.41      0.51        37
#
#     accuracy                           0.79       140
#    macro avg       0.75      0.67      0.69       140
# weighted avg       0.78      0.79      0.77       140

# %%
RocCurveDisplay.from_estimator(model, X_test, y_test)
plt.show()

# %% [markdown]
# THRESHOLD OPTIMIZATION

# %%
model.fit(X_train, y_train)

th_value = [i/100 for i in range(20,60)]
score = 0
score_list = []

for i in th_value:
  y_prob = model.predict_proba(X_val)[:,1]
  y_pred = np.where(y_prob>i,1,0)
  score_temp = f1_score(y_val, y_pred)
  score_list.append(score_temp)

  if score_temp > score :
    score = score_temp

    best_score = score
    best_th = i

# %%
sns.lineplot(x=th_value, y=score_list)
plt.show()

# %%
print('best threshold', best_th)
print('best score', best_score)
# Out:
# best threshold 0.47
# best score 0.676923076923077

# %%
model.fit(X_train_val, y_train_val)
y_prob = model.predict_proba(X_test)[:,1]
y_pred = np.where(y_prob>best_th,1,0)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86       103
#            1       0.62      0.43      0.51        37
#
#     accuracy                           0.78       140
#    macro avg       0.72      0.67      0.68       140
# weighted avg       0.76      0.78      0.76       140

# %% [markdown]
# > ## Resampling : Undersampling

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
rus = RandomUnderSampler()
X_under, y_under = rus.fit_resample(X_train_val, y_train_val) # undersampling the training set

# %% [markdown]
# other method you can try:
# 1. RandomOverSampler()
# 1. SMOTE()
# 1. NearMiss()

# %%
model_under = LogisticRegression()
model_under.fit(X_under, y_under)
y_pred = model_under.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.72      0.82       103
#            1       0.54      0.92      0.68        37
#
#     accuracy                           0.77       140
#    macro avg       0.75      0.82      0.75       140
# weighted avg       0.85      0.77      0.78       140

# %%
RocCurveDisplay.from_estimator(model_under, X_test, y_test)
plt.show()

# %% [markdown]
# > ## Penalized

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
model_balanced = LogisticRegression(class_weight = 'balanced') # penalized 'balanced'
model_balanced.fit(X_train_val, y_train_val)
y_pred = model_balanced.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.72      0.82       103
#            1       0.53      0.89      0.67        37
#
#     accuracy                           0.76       140
#    macro avg       0.74      0.81      0.74       140
# weighted avg       0.84      0.76      0.78       140

# %%
RocCurveDisplay.from_estimator(model_balanced, X_test, y_test)
plt.show()

# %% [markdown]
# > ## Summary

# %%
f1_no_tr = f1_score(y_test,model.predict(X_test))

y_prob_th = model.predict_proba(X_test)[:,1]
f1_no_tr_th = f1_score(y_test,np.where(y_prob_th > 0.5,1,0))

f1_under = f1_score(y_test,model_under.predict(X_test))
f1_model = f1_score(y_test,model_balanced.predict(X_test))

# %%
score_list = [f1_no_tr, f1_no_tr_th, f1_under,f1_model]
model_names = ['default','threshold optimization','random undersampling','algo basaed']
df_summary = pd.DataFrame({
    'method':model_names,
    'score':score_list
})
df_summary
# Out:
#                    method     score
# 0                 default  0.508475
# 1  threshold optimization  0.508475
# 2    random undersampling  0.680000
# 3             algo basaed  0.666667

# %% [markdown]
# From this summary you can see that we tried several methods to handle imbalance classification problem. The outcome is that a penalized regression can outperform another method for this case. For another case the result may differ.You can try more method as well or even optimized each method using hyperparameter tuning.

# %% [markdown]
# > # Combine Cross Validation with Balancing Method

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold, GridSearchCV
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler, NearMiss
from imblearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import classification_report, f1_score

import warnings

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
bankloan = pd.read_csv('bankloan.csv')

# %%
fitur = ['employ', 'debtinc', 'creddebt', 'othdebt']
target = ['default']

# %%
X = bankloan[fitur]
y = bankloan[target]

# %%
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X,
    y,
    stratify = y,
    test_size = 0.2,
    random_state = 1899)

# %% [markdown]
# > ## Resampling : SMOTE

# %% [markdown]
# SMOTE

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# When you want to combine cross validation and any resampling method it's very recommended for you to use Pipeline because it simplyfy your code and make sure that validation set and test set is not involved in the modeling. Using pipline will also work on hyperparameter tuning.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
smote = SMOTE()
model = LogisticRegression()

estimator = Pipeline([('balancing',smote),('clf',model)])

# %%
skf = StratifiedKFold(n_splits = 5)
model_cv = cross_val_score(estimator, X_train_val, y_train_val, cv = skf, scoring = 'f1')

# %%
print('cv score :', model_cv)
print('cv score mean :', model_cv.mean())
# Out:
# cv score : [0.54320988 0.60273973 0.65625    0.75       0.54285714]
# cv score mean : 0.61901134908555

# %% [markdown]
# > ## Penalized

# %% [markdown]
# You will not need pipeline to apply penalized method and it's also faster.

# %%
model =  LogisticRegression(class_weight = 'balanced')
skf = StratifiedKFold(n_splits = 5)
model_cv = cross_val_score(model, X_train_val, y_train_val, cv = skf, scoring = 'f1')

# %%
print('cv score :', model_cv)
print('cv score mean :', model_cv.mean())
# Out:
# cv score : [0.56097561 0.60273973 0.60869565 0.76190476 0.52173913]
# cv score mean : 0.6112109760593906

# %% [markdown]
# The better model is the penalized model

# %% [markdown]
# # Combine Hyperparameter Tuning with Balancing Method

# %% [markdown]
# > ## Hyperparameter Tuning Scenario

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# make the algorithm chains
smote = SMOTE()
model =  LogisticRegression()
estimator = Pipeline([('balancing',smote),('clf',model)])

# hyperparameter space
hyperparam_space = {
    'balancing__k_neighbors':[2,5,10,15,20],
    'clf__C':[100, 10, 1, 0.1, 0.01, 0.001],
    'clf__solver':['liblinear','newton-cg']
}

# stratified cross vaidation
skf = StratifiedKFold(n_splits = 5)

# hyperparameter tuning
grid_search = GridSearchCV(
    estimator, # model to tune
    param_grid = hyperparam_space, # hyperparameter space
    cv = skf, # evaluation method
    scoring = 'f1', # metrics
    n_jobs = -1 # use all cores
)

# %%
grid_search.fit(X_train_val, y_train_val)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=Pipeline(steps=[('balancing', SMOTE()),
#                                        ('clf', LogisticRegression())]),
#              n_jobs=-1,
#              param_grid={'balancing__k_neighbors': [2, 5, 10, 15, 20],
#                          'clf__C': [100, 10, 1, 0.1, 0.01, 0.001],
#                          'clf__solver': ['liblinear', 'newton-cg']},
#              scoring='f1')

# %%
print('best score',grid_search.best_score_)
print('best param',grid_search.best_params_)
# Out:
# best score 0.6236217950875304
# best param {'balancing__k_neighbors': 10, 'clf__C': 10, 'clf__solver': 'liblinear'}

# %%
pd.DataFrame(grid_search.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.021612      0.002168         0.015920        0.007671
# 1        0.037123      0.015637         0.015864        0.006261
# 2        0.023756      0.011256         0.012031        0.001091
# 3        0.033588      0.009778         0.022391        0.009169
# 4        0.023781      0.007124         0.014539        0.003894
# 5        0.024579      0.004639         0.013032        0.001767
# 6        0.021665      0.009790         0.013492        0.003740
# 7        0.024008      0.001984         0.012101        0.000809
# 8        0.017104      0.000651         0.012140        0.000646
# 9        0.028771      0.003894         0.013130        0.000589
# 10       0.020838      0.004500         0.014252        0.001695
# 11       0.037034      0.016591         0.023779        0.008969
# 12       0.040310      0.004973         0.026406        0.000959
# 13       0.028162      0.010082         0.014967        0.005943
# 14       0.020617      0.005199         0.012932        0.001703
# 15       0.026218      0.002364         0.012719        0.000731
# 16       0.020189      0.002213         0.015409        0.004001
# 17       0.023270      0.000880         0.011997        0.000490
# 18       0.021375      0.003937         0.013799        0.004570
# 19       0.023366      0.001242         0.012231        0.000601
# 20       0.017960      0.000739         0.011597        0.000208
# 21       0.025049      0.003811         0.012149        0.000792
# 22       0.018650      0.001491         0.016006        0.006771
# 23       0.023123      0.001311         0.015850        0.006860
# 24       0.018046      0.000923         0.013842        0.004328
# 25       0.023479      0.000964         0.012597        0.001083
# 26       0.018928      0.000867         0.013216        0.001309
# 27       0.022364      0.000291         0.015209        0.004075
# 28       0.020116      0.001471         0.012536        0.000322
# 29       0.025578      0.001171         0.012752        0.001076
# 30       0.018139      0.000860         0.012336        0.000321
# 31       0.023911      0.001697         0.013481        0.002393
# 32       0.019477      0.001584         0.011601        0.000400
# 33       0.022672      0.001329         0.011819        0.000351
# 34       0.023497      0.006401         0.015783        0.004655
# 35       0.026139      0.004155         0.012854        0.001548
# 36       0.018548      0.001267         0.012527        0.002081
# 37       0.023969      0.001897         0.012576        0.001015
# 38       0.020346      0.001604         0.012608        0.000818
# 39       0.025194      0.004233         0.011990        0.000333
# 40       0.018326      0.001034         0.011863        0.000278
# 41       0.024656      0.002452         0.012143        0.000956
# 42       0.018423      0.000513         0.012216        0.000506
# 43       0.025204      0.001458         0.012465        0.000882
# 44       0.020892      0.001742         0.012476        0.001169
# 45       0.029295      0.006303         0.013051        0.001322
# 46       0.019478      0.001226         0.012874        0.002048
# 47       0.028563      0.006760         0.013468        0.001101
# 48       0.019067      0.001230         0.012318        0.000592
# 49       0.024417      0.001127         0.012311        0.000705
# 50       0.020091      0.003018         0.012503        0.000666
# 51       0.024091      0.002008         0.013897        0.003117
# 52       0.018889      0.001585         0.011664        0.000160
# 53       0.024555      0.001790         0.012067        0.000641
# 54       0.019242      0.002210         0.012165        0.000434
# 55       0.024949      0.000711         0.016407        0.008020
# 56       0.018849      0.001376         0.012102        0.001308
# 57       0.023465      0.002253         0.014912        0.004740
# 58       0.023479      0.008899         0.012897        0.001077
# 59       0.023605      0.004502         0.011680        0.002404
#
#     param_balancing__k_neighbors  param_clf__C param_clf__solver  \
# 0                              2       100.000         liblinear
# 1                              2       100.000         newton-cg
# 2                              2        10.000         liblinear
# 3                              2        10.000         newton-cg
# 4                              2         1.000         liblinear
# 5                              2         1.000         newton-cg
# 6                              2         0.100         liblinear
# 7                              2         0.100         newton-cg
# 8                              2         0.010         liblinear
# 9                              2         0.010         newton-cg
# 10                             2         0.001         liblinear
# 11                             2         0.001         newton-cg
# 12                             5       100.000         liblinear
# 13                             5       100.000         newton-cg
# 14                             5        10.000         liblinear
# 15                             5        10.000         newton-cg
# 16                             5         1.000         liblinear
# 17                             5         1.000         newton-cg
# 18                             5         0.100         liblinear
# 19                             5         0.100         newton-cg
# 20                             5         0.010         liblinear
# 21                             5         0.010         newton-cg
# 22                             5         0.001         liblinear
# 23                             5         0.001         newton-cg
# 24                            10       100.000         liblinear
# 25                            10       100.000         newton-cg
# 26                            10        10.000         liblinear
# 27                            10        10.000         newton-cg
# 28                            10         1.000         liblinear
# 29                            10         1.000         newton-cg
# 30                            10         0.100         liblinear
# 31                            10         0.100         newton-cg
# 32                            10         0.010         liblinear
# 33                            10         0.010         newton-cg
# 34                            10         0.001         liblinear
# 35                            10         0.001         newton-cg
# 36                            15       100.000         liblinear
# 37                            15       100.000         newton-cg
# 38                            15        10.000         liblinear
# 39                            15        10.000         newton-cg
# 40                            15         1.000         liblinear
# 41                            15         1.000         newton-cg
# 42                            15         0.100         liblinear
# 43                            15         0.100         newton-cg
# 44                            15         0.010         liblinear
# 45                            15         0.010         newton-cg
# 46                            15         0.001         liblinear
# 47                            15         0.001         newton-cg
# 48                            20       100.000         liblinear
# 49                            20       100.000         newton-cg
# 50                            20        10.000         liblinear
# 51                            20        10.000         newton-cg
# 52                            20         1.000         liblinear
# 53                            20         1.000         newton-cg
# 54                            20         0.100         liblinear
# 55                            20         0.100         newton-cg
# 56                            20         0.010         liblinear
# 57                            20         0.010         newton-cg
# 58                            20         0.001         liblinear
# 59                            20         0.001         newton-cg
#
#                                                params  split0_test_score  \
# 0   {'balancing__k_neighbors': 2, 'clf__C': 100, '...           0.567901
# 1   {'balancing__k_neighbors': 2, 'clf__C': 100, '...           0.550000
# 2   {'balancing__k_neighbors': 2, 'clf__C': 10, 'c...           0.554217
# 3   {'balancing__k_neighbors': 2, 'clf__C': 10, 'c...           0.543210
# 4   {'balancing__k_neighbors': 2, 'clf__C': 1, 'cl...           0.538462
# 5   {'balancing__k_neighbors': 2, 'clf__C': 1, 'cl...           0.536585
# 6   {'balancing__k_neighbors': 2, 'clf__C': 0.1, '...           0.554217
# 7   {'balancing__k_neighbors': 2, 'clf__C': 0.1, '...           0.536585
# 8   {'balancing__k_neighbors': 2, 'clf__C': 0.01, ...           0.571429
# 9   {'balancing__k_neighbors': 2, 'clf__C': 0.01, ...           0.564103
# 10  {'balancing__k_neighbors': 2, 'clf__C': 0.001,...           0.564706
# 11  {'balancing__k_neighbors': 2, 'clf__C': 0.001,...           0.543210
# 12  {'balancing__k_neighbors': 5, 'clf__C': 100, '...           0.525000
# 13  {'balancing__k_neighbors': 5, 'clf__C': 100, '...           0.536585
# 14  {'balancing__k_neighbors': 5, 'clf__C': 10, 'c...           0.543210
# 15  {'balancing__k_neighbors': 5, 'clf__C': 10, 'c...           0.550000
# 16  {'balancing__k_neighbors': 5, 'clf__C': 1, 'cl...           0.525000
# 17  {'balancing__k_neighbors': 5, 'clf__C': 1, 'cl...           0.531646
# 18  {'balancing__k_neighbors': 5, 'clf__C': 0.1, '...           0.536585
# 19  {'balancing__k_neighbors': 5, 'clf__C': 0.1, '...           0.531646
# 20  {'balancing__k_neighbors': 5, 'clf__C': 0.01, ...           0.564706
# 21  {'balancing__k_neighbors': 5, 'clf__C': 0.01, ...           0.550000
# 22  {'balancing__k_neighbors': 5, 'clf__C': 0.001,...           0.564706
# 23  {'balancing__k_neighbors': 5, 'clf__C': 0.001,...           0.560976
# 24  {'balancing__k_neighbors': 10, 'clf__C': 100, ...           0.536585
# 25  {'balancing__k_neighbors': 10, 'clf__C': 100, ...           0.543210
# 26  {'balancing__k_neighbors': 10, 'clf__C': 10, '...           0.543210
# 27  {'balancing__k_neighbors': 10, 'clf__C': 10, '...           0.543210
# 28  {'balancing__k_neighbors': 10, 'clf__C': 1, 'c...           0.536585
# 29  {'balancing__k_neighbors': 10, 'clf__C': 1, 'c...           0.531646
# 30  {'balancing__k_neighbors': 10, 'clf__C': 0.1, ...           0.543210
# 31  {'balancing__k_neighbors': 10, 'clf__C': 0.1, ...           0.564103
# 32  {'balancing__k_neighbors': 10, 'clf__C': 0.01,...           0.554217
# 33  {'balancing__k_neighbors': 10, 'clf__C': 0.01,...           0.554217
# 34  {'balancing__k_neighbors': 10, 'clf__C': 0.001...           0.564706
# 35  {'balancing__k_neighbors': 10, 'clf__C': 0.001...           0.560976
# 36  {'balancing__k_neighbors': 15, 'clf__C': 100, ...           0.543210
# 37  {'balancing__k_neighbors': 15, 'clf__C': 100, ...           0.560976
# 38  {'balancing__k_neighbors': 15, 'clf__C': 10, '...           0.536585
# 39  {'balancing__k_neighbors': 15, 'clf__C': 10, '...           0.560976
# 40  {'balancing__k_neighbors': 15, 'clf__C': 1, 'c...           0.543210
# 41  {'balancing__k_neighbors': 15, 'clf__C': 1, 'c...           0.550000
# 42  {'balancing__k_neighbors': 15, 'clf__C': 0.1, ...           0.536585
# 43  {'balancing__k_neighbors': 15, 'clf__C': 0.1, ...           0.543210
# 44  {'balancing__k_neighbors': 15, 'clf__C': 0.01,...           0.578313
# 45  {'balancing__k_neighbors': 15, 'clf__C': 0.01,...           0.550000
# 46  {'balancing__k_neighbors': 15, 'clf__C': 0.001...           0.585366
# 47  {'balancing__k_neighbors': 15, 'clf__C': 0.001...           0.543210
# 48  {'balancing__k_neighbors': 20, 'clf__C': 100, ...           0.543210
# 49  {'balancing__k_neighbors': 20, 'clf__C': 100, ...           0.543210
# 50  {'balancing__k_neighbors': 20, 'clf__C': 10, '...           0.531646
# 51  {'balancing__k_neighbors': 20, 'clf__C': 10, '...           0.543210
# 52  {'balancing__k_neighbors': 20, 'clf__C': 1, 'c...           0.543210
# 53  {'balancing__k_neighbors': 20, 'clf__C': 1, 'c...           0.543210
# 54  {'balancing__k_neighbors': 20, 'clf__C': 0.1, ...           0.560976
# 55  {'balancing__k_neighbors': 20, 'clf__C': 0.1, ...           0.536585
# 56  {'balancing__k_neighbors': 20, 'clf__C': 0.01,...           0.564706
# 57  {'balancing__k_neighbors': 20, 'clf__C': 0.01,...           0.550000
# 58  {'balancing__k_neighbors': 20, 'clf__C': 0.001...           0.585366
# 59  {'balancing__k_neighbors': 20, 'clf__C': 0.001...           0.550000
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.602740           0.636364           0.738462
# 1            0.611111           0.636364           0.750000
# 2            0.586667           0.617647           0.709677
# 3            0.591549           0.646154           0.727273
# 4            0.586667           0.608696           0.750000
# 5            0.583333           0.626866           0.730159
# 6            0.594595           0.608696           0.738462
# 7            0.600000           0.608696           0.750000
# 8            0.625000           0.591549           0.746269
# 9            0.602740           0.626866           0.746269
# 10           0.558140           0.594595           0.710526
# 11           0.567568           0.628571           0.746269
# 12           0.613333           0.626866           0.750000
# 13           0.613333           0.646154           0.741935
# 14           0.602740           0.608696           0.750000
# 15           0.586667           0.636364           0.750000
# 16           0.602740           0.608696           0.750000
# 17           0.602740           0.617647           0.721311
# 18           0.613333           0.608696           0.750000
# 19           0.594595           0.608696           0.741935
# 20           0.632911           0.602740           0.716418
# 21           0.602740           0.608696           0.757576
# 22           0.558140           0.594595           0.710526
# 23           0.575342           0.637681           0.746269
# 24           0.594595           0.636364           0.761905
# 25           0.611111           0.617647           0.718750
# 26           0.613333           0.656250           0.741935
# 27           0.600000           0.617647           0.741935
# 28           0.591549           0.608696           0.754098
# 29           0.621622           0.636364           0.741935
# 30           0.613333           0.617647           0.730159
# 31           0.586667           0.666667           0.750000
# 32           0.625000           0.608696           0.716418
# 33           0.591549           0.617647           0.769231
# 34           0.571429           0.594595           0.739726
# 35           0.567568           0.637681           0.716418
# 36           0.594595           0.608696           0.741935
# 37           0.583333           0.626866           0.741935
# 38           0.611111           0.626866           0.741935
# 39           0.602740           0.626866           0.761905
# 40           0.594595           0.617647           0.741935
# 41           0.594595           0.626866           0.750000
# 42           0.594595           0.636364           0.761905
# 43           0.602740           0.636364           0.741935
# 44           0.632911           0.600000           0.727273
# 45           0.594595           0.617647           0.727273
# 46           0.558140           0.594595           0.729730
# 47           0.567568           0.617647           0.764706
# 48           0.586667           0.608696           0.738462
# 49           0.594595           0.626866           0.750000
# 50           0.602740           0.617647           0.750000
# 51           0.613333           0.608696           0.750000
# 52           0.586667           0.636364           0.750000
# 53           0.594595           0.656250           0.741935
# 54           0.613333           0.617647           0.716418
# 55           0.611111           0.646154           0.741935
# 56           0.632911           0.608696           0.716418
# 57           0.591549           0.617647           0.730159
# 58           0.558140           0.594595           0.729730
# 59           0.567568           0.637681           0.746269
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.521739         0.613441        0.073148               18
# 1            0.542857         0.618066        0.074939                7
# 2            0.542857         0.602213        0.059758               49
# 3            0.542857         0.610209        0.069813               29
# 4            0.555556         0.607876        0.075107               35
# 5            0.521739         0.599736        0.074949               51
# 6            0.542857         0.607765        0.069766               36
# 7            0.521739         0.603404        0.080826               47
# 8            0.567568         0.620363        0.066160                5
# 9            0.563380         0.620671        0.067256                4
# 10           0.519481         0.589489        0.065076               59
# 11           0.507463         0.598616        0.083715               54
# 12           0.521739         0.607388        0.083518               38
# 13           0.535211         0.614644        0.076942               14
# 14           0.555556         0.612040        0.073565               23
# 15           0.521739         0.608954        0.080280               33
# 16           0.521739         0.601635        0.082849               50
# 17           0.521739         0.599017        0.071872               53
# 18           0.542857         0.610294        0.076825               26
# 19           0.521739         0.599722        0.078800               52
# 20           0.567568         0.616868        0.055711                9
# 21           0.550725         0.613947        0.075985               16
# 22           0.519481         0.589489        0.065076               59
# 23           0.542857         0.612625        0.074045               21
# 24           0.521739         0.610237        0.086240               28
# 25           0.521739         0.602491        0.069073               48
# 26           0.563380         0.623622        0.071083                1
# 27           0.521739         0.604906        0.077054               45
# 28           0.542857         0.606757        0.078679               40
# 29           0.542857         0.614885        0.075849               12
# 30           0.521739         0.605218        0.072999               44
# 31           0.542857         0.622059        0.076476                2
# 32           0.563380         0.613542        0.057920               17
# 33           0.563380         0.619205        0.078249                6
# 34           0.512821         0.596655        0.076366               58
# 35           0.507463         0.598021        0.072238               55
# 36           0.542857         0.606259        0.072863               42
# 37           0.521739         0.606970        0.075565               39
# 38           0.542857         0.611871        0.074260               24
# 39           0.521739         0.614845        0.081839               13
# 40           0.542857         0.608049        0.073011               34
# 41           0.542857         0.612863        0.075085               20
# 42           0.542857         0.614461        0.082226               15
# 43           0.521739         0.609198        0.077977               30
# 44           0.567568         0.621213        0.057539                3
# 45           0.555556         0.609014        0.064200               31
# 46           0.519481         0.597462        0.071101               56
# 47           0.529412         0.604508        0.085554               46
# 48           0.555556         0.606518        0.069876               41
# 49           0.542857         0.611505        0.076262               25
# 50           0.542857         0.608978        0.077915               32
# 51           0.563380         0.615724        0.072226               11
# 52           0.521739         0.607596        0.081316               37
# 53           0.542857         0.615769        0.075612               10
# 54           0.542857         0.610246        0.060507               27
# 55           0.529412         0.613040        0.078171               19
# 56           0.563380         0.617222        0.056242                8
# 57           0.571429         0.612157        0.063090               22
# 58           0.519481         0.597462        0.071101               56
# 59           0.527778         0.605859        0.079260               43

# %% [markdown]
# > ## Model Performance Before Tuning

# %%
smote = SMOTE()
model =  LogisticRegression()

estimator = Pipeline([('balancing',smote),('clf',model)])

estimator.fit(X_train_val,y_train_val)
y_pred = estimator.predict(X_test)

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.71      0.81       103
#            1       0.52      0.89      0.66        37
#
#     accuracy                           0.76       140
#    macro avg       0.74      0.80      0.74       140
# weighted avg       0.84      0.76      0.77       140

# %% [markdown]
# > ## Model Performance After Tuning

# %%
grid_search.best_estimator_.fit(X_train_val,y_train_val)
y_pred = grid_search.best_estimator_.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.72      0.81       103
#            1       0.52      0.86      0.65        37
#
#     accuracy                           0.76       140
#    macro avg       0.73      0.79      0.73       140
# weighted avg       0.83      0.76      0.77       140

# %%
RocCurveDisplay.from_estimator(grid_search.best_estimator_, X_test, y_test)

# %% [markdown]
# # TASK :

# %% [markdown]
# Repeat the 'Resampling Method : Non Performing Loan' section by adding hyperparameter tuning in each method 'Resampling : Undersampling', and 'Penalized' only.
